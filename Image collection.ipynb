# %%
import cv2 

# Import uuid
import uuid

# Import Operating System
import os

# Import time
import time

# %%
IMAGES_PATH = 'D:\RealTimeObjectDetection\Tensorflow\workspace\images\collectedimages'

# %%
labels = ['hello', 'thanks', 'iloveyou', 'yes', 'no']
number_imgs = 10

# %%
for label in labels:
    # !mkdir {'D:\RealTimeObjectDetection\Tensorflow\workspace\images\collectedimages\\'+label}
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(10): 
        print('Collecting image {}'.format(imgnum))
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(4)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cap.release()
# Out:
# A subdirectory or file D:\RealTimeObjectDetection\Tensorflow\workspace\images\collectedimages\hello already exists.
# ...
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
#       9 imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
#      10 cv2.imwrite(imgname, frame)
# ---> 11 cv2.imshow('frame', frame)
#      12 time.sleep(4)
#      14 if cv2.waitKey(1) & 0xFF == ord('q'):
#
# error: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-8vfej43a\opencv\modules\highgui\src\window.cpp:679: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
cap.release()

# %%
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 cv2.destroyAllWindows()
#
# error: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-8vfej43a\opencv\modules\highgui\src\window.cpp:673: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'
